# %%
from ethopy_analysis.plots.utils import setup_plot_style
from ethopy_analysis.db.queries import get_sessions, get_performance
from ethopy_analysis.plots.animal import (
    plot_session_performance,
    plot_performance_liquid,
    plot_session_date,
    plot_trial_per_session,
)

from ethopy_analysis.plots.utils import setup_plot_style
# Set up plotting style
setup_plot_style("seaborn", font_size=12)

# %%
animal_id = 290
sessions = get_sessions(animal_id,  min_trials=20)

# %%
perfs = plot_session_performance(animal_id, sessions['session'].values,  perf_func = get_performance)

# %%
# show the performance vs liquid
animal_sessions = get_sessions(animal_id,  min_trials=20)
# # remove sessions
# animal_sessions_dj = animal_sessions_dj & 'session!=44'
plot_performance_liquid(animal_id, animal_sessions, xaxis = 'session') # xaxis = 'date' or 'session'

# %%
# check session per day
session_same_date = plot_session_date(animal_id, min_trials=1)

# %%
# check trials per session
plot_trial_per_session(animal_id, min_trials=30)
